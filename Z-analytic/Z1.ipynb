# %%
import sys
sys.path.append("python/")

import sympy as sp
import Z1sym
import symbase
from sympy.printing.c import C99CodePrinter

# %% [markdown]
# # Момент $\left< Y_{l_1}^{m_1}(\phi, \theta) Y_{l_2}^{m_2*}(\phi, \theta) \right>$

# %%
p = Z1sym.p
px, py, pz = Z1sym.px, Z1sym.py, Z1sym.pz
Z1 = Z1sym.Z1

# %%
im1, im2, il1, il2 = sp.symbols("i_{m1} i_{m2} i_{l1} i_{l2}", integer=True, positive=True)
Z = sp.Symbol("Z")


def get_norm(l, m):
    norm = 1/sp.sqrt(2*sp.pi)
    norm *= sp.sqrt(sp.factorial(l-m)/sp.factorial(l+m)*(2*l+1)/2)
    if m < 0:
        m = abs(m)
        norm *= (-1)**m*sp.factorial(l-m)/sp.factorial(l+m)
    norm *= (-1)**m*2**l
    return norm


def sign(x):
    if x >= 0:
        return 1
    return -1


def binomial(n, m):
    return sp.gamma(n + 1)/(sp.gamma(m + 1)*sp.gamma(n - m + 1))


def get_moment(l1, l2, m1, m2):
    norm = get_norm(l1, m1)
    norm *= get_norm(l2, m2)
    sm1, sm2 = sign(m1), sign(m2)
    m1, m2 = abs(m1), abs(m2)

    # diff x: im1+im2
    # diff y: m1+m2-im1-im2
    # diff z: il1+il2-m1-m2

    D = sp.IndexedBase("D")
    expr = sp.Sum((sm1*sp.I)**(m1-im1)*D[im1+im2, m1+m2-im1-im2, il1+il2-m1-m2], (im1, 0, m1))
    expr = sp.Sum(expr*(-sm2*sp.I)**(m2-im2), (im2, 0, m2))
    expr = sp.Sum(expr*sp.factorial(il1)/sp.factorial(il1-m1)*binomial(l1, il1)*binomial((l1+il1-1)/2, l1), (il1, m1, l1))
    expr = sp.Sum(expr*sp.factorial(il2)/sp.factorial(il2-m2)*binomial(l2, il2)*binomial((l2+il2-1)/2, l2), (il2, m2, l2))

    expr = symbase.eval_sum_direct(expr.factor(), recursive=1)

    expr = expr.replace(sp.Indexed, lambda *args: Z1.replace(p, sp.sqrt(px**2+py**2+pz**2)).diff((px, args[1]), (py, args[2]), (pz, args[3])))
    expr = expr.subs(sp.sqrt(px**2+py**2+pz**2), p).expand()

    expr = (expr/Z1).expand()
    norm *= Z1/(sp.sinh(p)/p)*Z

    expr = expr.subs(Z1sym.subs_exp_to_m).expand()
    # expr = expr.factor()
    # expr *= norm

    lin_expr = expr.replace(Z1sym.m, p/3).factor()

    expr = C99CodePrinter().doprint(expr.subs({Z1sym.m: sp.Symbol("m")}))
    norm = C99CodePrinter().doprint(norm)
    lin_expr = C99CodePrinter().doprint(lin_expr)
    return norm, expr, lin_expr

# %%
lmax = 2

for l1 in range(lmax+1):
    for l2 in range(lmax+1):
        for m1 in range(-l1, l1+1):
            for m2 in range(-l2, l2+1):
                norm, expr, lin_expr = get_moment(l1, l2, m1, m2)
                print(f"if (l1 == {l1} && l2 == {l2} && m1 == {m1} && m2 == {m2})")
                print(f"return {norm} * (fabs(p) > 1e-4 ? {expr} : {lin_expr});")
# Out:
# if (l1 == 0 && l2 == 0 && m1 == 0 && m2 == 0)
# return Z * (fabs(p) > 1e-4 ? 1 : 1);
# if (l1 == 0 && l2 == 1 && m1 == 0 && m2 == -1)
# return sqrt(6)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_x/p + (1.0/2.0)*I*m*p_y/p : (1.0/6.0)*(p_x + I*p_y));
# if (l1 == 0 && l2 == 1 && m1 == 0 && m2 == 0)
# return 2*sqrt(3)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_z/p : (1.0/6.0)*p_z);
# if (l1 == 0 && l2 == 1 && m1 == 0 && m2 == 1)
# return -sqrt(6)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_x/p - 1.0/2.0*I*m*p_y/p : (1.0/6.0)*(p_x - I*p_y));
# if (l1 == 0 && l2 == 2 && m1 == 0 && m2 == -2)
# return (1.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*pow(p_x, 2)/pow(p, 3) - 9.0/4.0*I*m*p_x*p_y/pow(p, 3) + (9.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (3.0/4.0)*pow(p_x, 2)/pow(p, 2) + (3.0/4.0)*I*p_x*p_y/pow(p, 2) - 3.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 0 && l2 == 2 && m1 == 0 && m2 == -1)
# return (2.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*p_x*p_z/pow(p, 3) - 9.0/4.0*I*m*p_y*p_z/pow(p, 3) + (3.0/4.0)*p_x*p_z/pow(p, 2) + (3.0/4.0)*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 0 && l2 == 2 && m1 == 0 && m2 == 0)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m/p - 9.0/8.0*m*pow(p_z, 2)/pow(p, 3) - 1.0/8.0 + (3.0/8.0)*pow(p_z, 2)/pow(p, 2) : 0);
# if (l1 == 0 && l2 == 2 && m1 == 0 && m2 == 1)
# return -2.0/3.0*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*p_x*p_z/pow(p, 3) + (9.0/4.0)*I*m*p_y*p_z/pow(p, 3) + (3.0/4.0)*p_x*p_z/pow(p, 2) - 3.0/4.0*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 0 && l2 == 2 && m1 == 0 && m2 == 2)
# return (1.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*pow(p_x, 2)/pow(p, 3) + (9.0/4.0)*I*m*p_x*p_y/pow(p, 3) + (9.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (3.0/4.0)*pow(p_x, 2)/pow(p, 2) - 3.0/4.0*I*p_x*p_y/pow(p, 2) - 3.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 0 && m1 == -1 && m2 == 0)
# return sqrt(6)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_x/p - 1.0/2.0*I*m*p_y/p : (1.0/6.0)*(p_x - I*p_y));
# if (l1 == 1 && l2 == 0 && m1 == 0 && m2 == 0)
# return 2*sqrt(3)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_z/p : (1.0/6.0)*p_z);
# if (l1 == 1 && l2 == 0 && m1 == 1 && m2 == 0)
# return -sqrt(6)*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m*p_x/p + (1.0/2.0)*I*m*p_y/p : (1.0/6.0)*(p_x + I*p_y));
# if (l1 == 1 && l2 == 1 && m1 == -1 && m2 == -1)
# return 6*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m/p - 3.0/4.0*m*pow(p_x, 2)/pow(p, 3) - 3.0/4.0*m*pow(p_y, 2)/pow(p, 3) + (1.0/4.0)*pow(p_x, 2)/pow(p, 2) + (1.0/4.0)*pow(p_y, 2)/pow(p, 2) : 1.0/6.0);
# if (l1 == 1 && l2 == 1 && m1 == -1 && m2 == 0)
# return 6*M_SQRT2*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*p_x*p_z/pow(p, 3) + (3.0/4.0)*I*m*p_y*p_z/pow(p, 3) + (1.0/4.0)*p_x*p_z/pow(p, 2) - 1.0/4.0*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == -1 && m2 == 1)
# return -6*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*pow(p_x, 2)/pow(p, 3) + (3.0/2.0)*I*m*p_x*p_y/pow(p, 3) + (3.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (1.0/4.0)*pow(p_x, 2)/pow(p, 2) - 1.0/2.0*I*p_x*p_y/pow(p, 2) - 1.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == 0 && m2 == -1)
# return 6*M_SQRT2*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*p_x*p_z/pow(p, 3) - 3.0/4.0*I*m*p_y*p_z/pow(p, 3) + (1.0/4.0)*p_x*p_z/pow(p, 2) + (1.0/4.0)*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == 0 && m2 == 0)
# return 12*Z * (fabs(p) > 1e-4 ? (1.0/4.0)*m/p - 3.0/4.0*m*pow(p_z, 2)/pow(p, 3) + (1.0/4.0)*pow(p_z, 2)/pow(p, 2) : 1.0/12.0);
# if (l1 == 1 && l2 == 1 && m1 == 0 && m2 == 1)
# return -6*M_SQRT2*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*p_x*p_z/pow(p, 3) + (3.0/4.0)*I*m*p_y*p_z/pow(p, 3) + (1.0/4.0)*p_x*p_z/pow(p, 2) - 1.0/4.0*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == 1 && m2 == -1)
# return -6*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*pow(p_x, 2)/pow(p, 3) - 3.0/2.0*I*m*p_x*p_y/pow(p, 3) + (3.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (1.0/4.0)*pow(p_x, 2)/pow(p, 2) + (1.0/2.0)*I*p_x*p_y/pow(p, 2) - 1.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == 1 && m2 == 0)
# return -6*M_SQRT2*Z * (fabs(p) > 1e-4 ? -3.0/4.0*m*p_x*p_z/pow(p, 3) - 3.0/4.0*I*m*p_y*p_z/pow(p, 3) + (1.0/4.0)*p_x*p_z/pow(p, 2) + (1.0/4.0)*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 1 && l2 == 1 && m1 == 1 && m2 == 1)
# return 6*Z * (fabs(p) > 1e-4 ? (1.0/2.0)*m/p - 3.0/4.0*m*pow(p_x, 2)/pow(p, 3) - 3.0/4.0*m*pow(p_y, 2)/pow(p, 3) + (1.0/4.0)*pow(p_x, 2)/pow(p, 2) + (1.0/4.0)*pow(p_y, 2)/pow(p, 2) : 1.0/6.0);
# if (l1 == 1 && l2 == 2 && m1 == -1 && m2 == -2)
# return 2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 27.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*pow(p_y, 3)/pow(p, 3) - 27.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)/pow(p, 5) + (9.0/8.0)*p_x/pow(p, 2) + (9.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) - 15.0/8.0*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x - I*p_y)*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == -1 && m2 == -1)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 3) - 9.0/4.0*m*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 5) + (3.0/4.0)*p_z/pow(p, 2) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == -1 && m2 == 0)
# return 4*sqrt(30)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_x/p + (1.0/16.0)*I*m*p_y/p + (3.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*m*p_x/pow(p, 3) - 3.0/16.0*I*m*p_y*pow(p_z, 2)/pow(p, 3) + (9.0/16.0)*I*m*p_y/pow(p, 3) + (45.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 5) - 45.0/16.0*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/16.0)*p_x/pow(p, 2) - 3.0/16.0*I*p_y/pow(p, 2) - 15.0/16.0*p_x*pow(p_z, 2)/pow(p, 4) + (15.0/16.0)*I*p_y*pow(p_z, 2)/pow(p, 4) : -1.0/48.0*(pow(p, 2) - 3*pow(p_z, 2))*(p_x - I*p_y)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == -1 && m2 == 1)
# return -4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) - 3.0/4.0*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) - 45.0/4.0*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) + (15.0/4.0)*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*pow(p_x - I*p_y, 2)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == -1 && m2 == 2)
# return 2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 3.0/4.0*I*m*pow(p_x, 2)*p_y/pow(p, 3) - 3.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*pow(p_y, 3)/pow(p, 3) - 9.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) - 45.0/4.0*I*m*pow(p_x, 2)*p_y/pow(p, 5) - 45.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) + (3.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) + (15.0/4.0)*I*pow(p_x, 2)*p_y/pow(p, 4) + (15.0/4.0)*p_x*pow(p_y, 2)/pow(p, 4) - 15.0/8.0*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x - I*p_y)*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 0 && m2 == -2)
# return 2*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 0 && m2 == -1)
# return 4*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*p_y*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 5) + (45.0/8.0)*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) + (3.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*p_x*pow(p_z, 2)/pow(p, 4) - 15.0/8.0*I*p_y*pow(p_z, 2)/pow(p, 4) : (1.0/8.0)*pow(p_z, 2)*(p_x + I*p_y)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 0 && m2 == 0)
# return 8*sqrt(15)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_z/p + (3.0/16.0)*m*pow(p_z, 3)/pow(p, 3) - 27.0/16.0*m*p_z/pow(p, 3) + (45.0/16.0)*m*pow(p_z, 3)/pow(p, 5) + (9.0/16.0)*p_z/pow(p, 2) - 15.0/16.0*pow(p_z, 3)/pow(p, 4) : -1.0/48.0*p_z*(pow(p, 2) - 3*pow(p_z, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 0 && m2 == 1)
# return -4*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*p_y*pow(p_z, 2)/pow(p, 3) + (9.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 5) - 45.0/8.0*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) - 3.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*p_x*pow(p_z, 2)/pow(p, 4) + (15.0/8.0)*I*p_y*pow(p_z, 2)/pow(p, 4) : (1.0/8.0)*pow(p_z, 2)*(p_x - I*p_y)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 0 && m2 == 2)
# return 2*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) - 3.0/8.0*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) - 45.0/8.0*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) + (15.0/8.0)*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 1 && m2 == -2)
# return -2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) + (3.0/4.0)*I*m*pow(p_x, 2)*p_y/pow(p, 3) - 3.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*pow(p_y, 3)/pow(p, 3) + (9.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) + (45.0/4.0)*I*m*pow(p_x, 2)*p_y/pow(p, 5) - 45.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) - 3.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) - 15.0/4.0*I*pow(p_x, 2)*p_y/pow(p, 4) + (15.0/4.0)*p_x*pow(p_y, 2)/pow(p, 4) + (15.0/8.0)*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x + I*p_y)*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 1 && m2 == -1)
# return -4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/4.0)*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/4.0)*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/4.0*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*pow(p_x + I*p_y, 2)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 1 && m2 == 0)
# return -4*sqrt(30)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_x/p - 1.0/16.0*I*m*p_y/p + (3.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*m*p_x/pow(p, 3) + (3.0/16.0)*I*m*p_y*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*I*m*p_y/pow(p, 3) + (45.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 5) + (45.0/16.0)*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/16.0)*p_x/pow(p, 2) + (3.0/16.0)*I*p_y/pow(p, 2) - 15.0/16.0*p_x*pow(p_z, 2)/pow(p, 4) - 15.0/16.0*I*p_y*pow(p_z, 2)/pow(p, 4) : -1.0/48.0*(pow(p, 2) - 3*pow(p_z, 2))*(p_x + I*p_y)/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 1 && m2 == 1)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 3) - 9.0/4.0*m*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 5) + (3.0/4.0)*p_z/pow(p, 2) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + pow(p_y, 2))/pow(p, 2));
# if (l1 == 1 && l2 == 2 && m1 == 1 && m2 == 2)
# return -2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 27.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*pow(p_y, 3)/pow(p, 3) + (27.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)/pow(p, 5) + (9.0/8.0)*p_x/pow(p, 2) - 9.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) + (15.0/8.0)*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x + I*p_y)*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 0 && m1 == -2 && m2 == 0)
# return (1.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*pow(p_x, 2)/pow(p, 3) + (9.0/4.0)*I*m*p_x*p_y/pow(p, 3) + (9.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (3.0/4.0)*pow(p_x, 2)/pow(p, 2) - 3.0/4.0*I*p_x*p_y/pow(p, 2) - 3.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 2 && l2 == 0 && m1 == -1 && m2 == 0)
# return (2.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*p_x*p_z/pow(p, 3) + (9.0/4.0)*I*m*p_y*p_z/pow(p, 3) + (3.0/4.0)*p_x*p_z/pow(p, 2) - 3.0/4.0*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 2 && l2 == 0 && m1 == 0 && m2 == 0)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m/p - 9.0/8.0*m*pow(p_z, 2)/pow(p, 3) - 1.0/8.0 + (3.0/8.0)*pow(p_z, 2)/pow(p, 2) : 0);
# if (l1 == 2 && l2 == 0 && m1 == 1 && m2 == 0)
# return -2.0/3.0*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*p_x*p_z/pow(p, 3) - 9.0/4.0*I*m*p_y*p_z/pow(p, 3) + (3.0/4.0)*p_x*p_z/pow(p, 2) + (3.0/4.0)*I*p_y*p_z/pow(p, 2) : 0);
# if (l1 == 2 && l2 == 0 && m1 == 2 && m2 == 0)
# return (1.0/3.0)*sqrt(30)*Z * (fabs(p) > 1e-4 ? -9.0/4.0*m*pow(p_x, 2)/pow(p, 3) - 9.0/4.0*I*m*p_x*p_y/pow(p, 3) + (9.0/4.0)*m*pow(p_y, 2)/pow(p, 3) + (3.0/4.0)*pow(p_x, 2)/pow(p, 2) + (3.0/4.0)*I*p_x*p_y/pow(p, 2) - 3.0/4.0*pow(p_y, 2)/pow(p, 2) : 0);
# if (l1 == 2 && l2 == 1 && m1 == -2 && m2 == -1)
# return 2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 27.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*pow(p_y, 3)/pow(p, 3) + (27.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)/pow(p, 5) + (9.0/8.0)*p_x/pow(p, 2) - 9.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) + (15.0/8.0)*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x + I*p_y)*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == -2 && m2 == 0)
# return 2*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) - 3.0/8.0*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) - 45.0/8.0*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) + (15.0/8.0)*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == -2 && m2 == 1)
# return -2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 3.0/4.0*I*m*pow(p_x, 2)*p_y/pow(p, 3) - 3.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*pow(p_y, 3)/pow(p, 3) - 9.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) - 45.0/4.0*I*m*pow(p_x, 2)*p_y/pow(p, 5) - 45.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) + (3.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) + (15.0/4.0)*I*pow(p_x, 2)*p_y/pow(p, 4) + (15.0/4.0)*p_x*pow(p_y, 2)/pow(p, 4) - 15.0/8.0*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x - I*p_y)*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == -1 && m2 == -1)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 3) - 9.0/4.0*m*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 5) + (3.0/4.0)*p_z/pow(p, 2) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == -1 && m2 == 0)
# return 4*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*p_y*pow(p_z, 2)/pow(p, 3) + (9.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 5) - 45.0/8.0*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) - 3.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*p_x*pow(p_z, 2)/pow(p, 4) + (15.0/8.0)*I*p_y*pow(p_z, 2)/pow(p, 4) : (1.0/8.0)*pow(p_z, 2)*(p_x - I*p_y)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == -1 && m2 == 1)
# return -4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) - 3.0/4.0*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) - 45.0/4.0*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) + (15.0/4.0)*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*pow(p_x - I*p_y, 2)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 0 && m2 == -1)
# return 4*sqrt(30)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_x/p - 1.0/16.0*I*m*p_y/p + (3.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*m*p_x/pow(p, 3) + (3.0/16.0)*I*m*p_y*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*I*m*p_y/pow(p, 3) + (45.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 5) + (45.0/16.0)*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/16.0)*p_x/pow(p, 2) + (3.0/16.0)*I*p_y/pow(p, 2) - 15.0/16.0*p_x*pow(p_z, 2)/pow(p, 4) - 15.0/16.0*I*p_y*pow(p_z, 2)/pow(p, 4) : -1.0/48.0*(pow(p, 2) - 3*pow(p_z, 2))*(p_x + I*p_y)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 0 && m2 == 0)
# return 8*sqrt(15)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_z/p + (3.0/16.0)*m*pow(p_z, 3)/pow(p, 3) - 27.0/16.0*m*p_z/pow(p, 3) + (45.0/16.0)*m*pow(p_z, 3)/pow(p, 5) + (9.0/16.0)*p_z/pow(p, 2) - 15.0/16.0*pow(p_z, 3)/pow(p, 4) : -1.0/48.0*p_z*(pow(p, 2) - 3*pow(p_z, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 0 && m2 == 1)
# return -4*sqrt(30)*Z * (fabs(p) > 1e-4 ? -1.0/16.0*m*p_x/p + (1.0/16.0)*I*m*p_y/p + (3.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/16.0*m*p_x/pow(p, 3) - 3.0/16.0*I*m*p_y*pow(p_z, 2)/pow(p, 3) + (9.0/16.0)*I*m*p_y/pow(p, 3) + (45.0/16.0)*m*p_x*pow(p_z, 2)/pow(p, 5) - 45.0/16.0*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/16.0)*p_x/pow(p, 2) - 3.0/16.0*I*p_y/pow(p, 2) - 15.0/16.0*p_x*pow(p_z, 2)/pow(p, 4) + (15.0/16.0)*I*p_y*pow(p_z, 2)/pow(p, 4) : -1.0/48.0*(pow(p, 2) - 3*pow(p_z, 2))*(p_x - I*p_y)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 1 && m2 == -1)
# return -4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/4.0)*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/4.0)*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/4.0*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*pow(p_x + I*p_y, 2)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 1 && m2 == 0)
# return -4*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*p_y*pow(p_z, 2)/pow(p, 3) - 9.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*p_x*pow(p_z, 2)/pow(p, 5) + (45.0/8.0)*I*m*p_y*pow(p_z, 2)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) + (3.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*p_x*pow(p_z, 2)/pow(p, 4) - 15.0/8.0*I*p_y*pow(p_z, 2)/pow(p, 4) : (1.0/8.0)*pow(p_z, 2)*(p_x + I*p_y)/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 1 && m2 == 1)
# return 4*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 3) - 9.0/4.0*m*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*p_z/pow(p, 5) + (3.0/4.0)*p_z/pow(p, 2) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 2 && m2 == -1)
# return 2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) + (3.0/4.0)*I*m*pow(p_x, 2)*p_y/pow(p, 3) - 3.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 3) - 9.0/8.0*m*p_x/pow(p, 3) - 3.0/8.0*I*m*pow(p_y, 3)/pow(p, 3) + (9.0/8.0)*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) + (45.0/4.0)*I*m*pow(p_x, 2)*p_y/pow(p, 5) - 45.0/4.0*m*p_x*pow(p_y, 2)/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)/pow(p, 5) + (3.0/8.0)*p_x/pow(p, 2) - 3.0/8.0*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) - 15.0/4.0*I*pow(p_x, 2)*p_y/pow(p, 4) + (15.0/4.0)*p_x*pow(p_y, 2)/pow(p, 4) + (15.0/8.0)*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x + I*p_y)*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 2 && m2 == 0)
# return 2*sqrt(10)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 3) + (3.0/8.0)*I*m*p_x*p_y*p_z/pow(p, 3) - 3.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 2)*p_z/pow(p, 5) + (45.0/8.0)*I*m*p_x*p_y*p_z/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*p_z/pow(p, 5) - 15.0/8.0*pow(p_x, 2)*p_z/pow(p, 4) - 15.0/8.0*I*p_x*p_y*p_z/pow(p, 4) + (15.0/8.0)*pow(p_y, 2)*p_z/pow(p, 4) : (1.0/8.0)*p_z*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 1 && m1 == 2 && m2 == 1)
# return -2*sqrt(5)*Z * (fabs(p) > 1e-4 ? (3.0/8.0)*m*pow(p_x, 3)/pow(p, 3) - 27.0/8.0*m*p_x/pow(p, 3) + (3.0/8.0)*I*m*pow(p_y, 3)/pow(p, 3) - 27.0/8.0*I*m*p_y/pow(p, 3) + (45.0/8.0)*m*pow(p_x, 3)/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)/pow(p, 5) + (9.0/8.0)*p_x/pow(p, 2) + (9.0/8.0)*I*p_y/pow(p, 2) - 15.0/8.0*pow(p_x, 3)/pow(p, 4) - 15.0/8.0*I*pow(p_y, 3)/pow(p, 4) : (1.0/8.0)*(p_x - I*p_y)*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 2));
# if (l1 == 2 && l2 == 2 && m1 == -2 && m2 == -2)
# return (10.0/3.0)*Z * (fabs(p) > 1e-4 ? (45.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (45.0/16.0)*m*pow(p_y, 2)/pow(p, 3) - 135.0/16.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 4)/pow(p, 5) + (45.0/8.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 5) + (675.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 4)/pow(p, 5) + (675.0/16.0)*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 4)/pow(p, 7) + (945.0/16.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 4)/pow(p, 7) + (45.0/16.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 4)/pow(p, 4) - 9.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 4) - 225.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/16.0)*pow(p_y, 4)/pow(p, 4) - 225.0/16.0*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 4)/pow(p, 6) - 315.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 6) + (315.0/16.0)*pow(p_y, 4)/pow(p, 6) : (3.0/16.0)*(5*pow(p, 2)*pow(p_x, 2) + 5*pow(p, 2)*pow(p_y, 2) - 7*pow(p_x, 4) + 7*pow(p_x, 2)*pow(p_y, 2) - 7*pow(p_y, 4))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -2 && m2 == -1)
# return (20.0/3.0)*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*p_x*p_z/pow(p, 3) - 27.0/16.0*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (405.0/16.0)*m*p_x*p_z/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)*p_z/pow(p, 5) - 405.0/16.0*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) + (945.0/16.0)*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 135.0/16.0*p_x*p_z/pow(p, 4) - 9.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 4) + (135.0/16.0)*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) - 315.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(3*pow(p, 2)*p_x - 3*I*pow(p, 2)*p_y - 7*pow(p_x, 3) + 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -2 && m2 == 0)
# return (20.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) - 9.0/16.0*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*m*pow(p_x, 2)/pow(p, 5) + (45.0/16.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*I*m*p_x*p_y/pow(p, 5) + (45.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/32.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) - 3.0/32.0*pow(p_x, 2)/pow(p, 2) + (3.0/32.0)*I*p_x*p_y/pow(p, 2) + (3.0/32.0)*pow(p_y, 2)/pow(p, 2) + (9.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*pow(p_x, 2)/pow(p, 4) - 9.0/32.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*I*p_x*p_y/pow(p, 4) - 9.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*pow(p_y, 2)/pow(p, 4) + (315.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/32.0)*(pow(p, 2) - 7*pow(p_z, 2))*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -2 && m2 == 1)
# return -20.0/3.0*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*p_x*p_z/pow(p, 3) + (9.0/16.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (45.0/4.0)*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 5) + (45.0/4.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 5) + (135.0/16.0)*m*p_x*p_z/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)*p_z/pow(p, 5) + (135.0/16.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) + (945.0/8.0)*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 7) + (945.0/8.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 7) - 945.0/16.0*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 9.0/8.0*I*pow(p_x, 2)*p_y*p_z/pow(p, 4) - 9.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 4) - 45.0/16.0*p_x*p_z/pow(p, 4) + (9.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 4) - 45.0/16.0*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) - 315.0/8.0*I*pow(p_x, 2)*p_y*p_z/pow(p, 6) - 315.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 6) + (315.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(pow(p, 2)*p_x + I*pow(p, 2)*p_y - 7*pow(p_x, 3) + 14*I*pow(p_x, 2)*p_y + 14*p_x*pow(p_y, 2) - 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -2 && m2 == 2)
# return (10.0/3.0)*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (27.0/16.0)*m*pow(p_y, 2)/pow(p, 3) - 81.0/16.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 4)/pow(p, 5) + (45.0/4.0)*I*m*pow(p_x, 3)*p_y/pow(p, 5) + (135.0/8.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 5) + (405.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/4.0*I*m*p_x*pow(p_y, 3)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 4)/pow(p, 5) + (405.0/16.0)*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 4)/pow(p, 7) + (945.0/8.0)*I*m*pow(p_x, 3)*p_y/pow(p, 7) + (2835.0/16.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 7) - 945.0/8.0*I*m*p_x*pow(p_y, 3)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 4)/pow(p, 7) + (27.0/16.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 4)/pow(p, 4) - 9.0/8.0*I*pow(p_x, 3)*p_y/pow(p, 4) - 27.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 4) - 135.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/8.0)*I*p_x*pow(p_y, 3)/pow(p, 4) + (9.0/16.0)*pow(p_y, 4)/pow(p, 4) - 135.0/16.0*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 4)/pow(p, 6) - 315.0/8.0*I*pow(p_x, 3)*p_y/pow(p, 6) - 945.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 6) + (315.0/8.0)*I*p_x*pow(p_y, 3)/pow(p, 6) + (315.0/16.0)*pow(p_y, 4)/pow(p, 6) : (3.0/16.0)*(3*pow(p, 2)*pow(p_x, 2) + 3*pow(p, 2)*pow(p_y, 2) - 7*pow(p_x, 4) + 14*I*pow(p_x, 3)*p_y + 21*pow(p_x, 2)*pow(p_y, 2) - 14*I*p_x*pow(p_y, 3) - 7*pow(p_y, 4))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -1 && m2 == -2)
# return (20.0/3.0)*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*p_x*p_z/pow(p, 3) + (27.0/16.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (405.0/16.0)*m*p_x*p_z/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)*p_z/pow(p, 5) + (405.0/16.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) - 945.0/16.0*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 135.0/16.0*p_x*p_z/pow(p, 4) + (9.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 4) - 135.0/16.0*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) + (315.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(3*pow(p, 2)*p_x + 3*I*pow(p, 2)*p_y - 7*pow(p_x, 3) - 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -1 && m2 == -1)
# return (40.0/3.0)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (9.0/16.0)*m*pow(p_y, 2)/pow(p, 3) + (9.0/8.0)*m*pow(p_z, 2)/pow(p, 3) - 27.0/8.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_y, 2)/pow(p, 5) + (135.0/8.0)*m*pow(p_z, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) + (9.0/8.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/16.0)*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_y, 2)/pow(p, 4) - 45.0/8.0*pow(p_z, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) + (315.0/16.0)*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/16.0)*(pow(p, 2)*pow(p_x, 2) + pow(p, 2)*pow(p_y, 2) + 2*pow(p, 2)*pow(p_z, 2) - 7*pow(p_x, 2)*pow(p_z, 2) - 7*pow(p_y, 2)*pow(p_z, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -1 && m2 == 0)
# return (40.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/8.0)*m*p_x*p_z/pow(p, 3) - 9.0/8.0*I*m*p_y*p_z/pow(p, 3) - 45.0/16.0*m*p_x*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*m*p_x*p_z/pow(p, 5) + (45.0/16.0)*I*m*p_y*pow(p_z, 3)/pow(p, 5) - 405.0/32.0*I*m*p_y*p_z/pow(p, 5) - 945.0/32.0*m*p_x*pow(p_z, 3)/pow(p, 7) + (945.0/32.0)*I*m*p_y*pow(p_z, 3)/pow(p, 7) - 3.0/32.0*p_x*p_z/pow(p, 2) + (3.0/32.0)*I*p_y*p_z/pow(p, 2) + (9.0/32.0)*p_x*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*p_x*p_z/pow(p, 4) - 9.0/32.0*I*p_y*pow(p_z, 3)/pow(p, 4) + (135.0/32.0)*I*p_y*p_z/pow(p, 4) + (315.0/32.0)*p_x*pow(p_z, 3)/pow(p, 6) - 315.0/32.0*I*p_y*pow(p_z, 3)/pow(p, 6) : (3.0/32.0)*p_z*(3*pow(p, 2) - 7*pow(p_z, 2))*(p_x - I*p_y)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -1 && m2 == 1)
# return -40.0/3.0*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) - 9.0/8.0*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/8.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_x, 2)/pow(p, 5) + (45.0/4.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) - 135.0/8.0*I*m*p_x*p_y/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/16.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) + (945.0/8.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) + (9.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_x, 2)/pow(p, 4) - 9.0/8.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) + (45.0/8.0)*I*p_x*p_y/pow(p, 4) - 9.0/16.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/16.0)*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) - 315.0/8.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/16.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/16.0)*(pow(p, 2) - 7*pow(p_z, 2))*pow(p_x - I*p_y, 2)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == -1 && m2 == 2)
# return (20.0/3.0)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*p_x*p_z/pow(p, 3) + (9.0/16.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (45.0/4.0)*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 5) + (45.0/4.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 5) + (135.0/16.0)*m*p_x*p_z/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)*p_z/pow(p, 5) + (135.0/16.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) + (945.0/8.0)*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 7) + (945.0/8.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 7) - 945.0/16.0*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 9.0/8.0*I*pow(p_x, 2)*p_y*p_z/pow(p, 4) - 9.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 4) - 45.0/16.0*p_x*p_z/pow(p, 4) + (9.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 4) - 45.0/16.0*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) - 315.0/8.0*I*pow(p_x, 2)*p_y*p_z/pow(p, 6) - 315.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 6) + (315.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(pow(p, 2)*p_x + I*pow(p, 2)*p_y - 7*pow(p_x, 3) + 14*I*pow(p_x, 2)*p_y + 14*p_x*pow(p_y, 2) - 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 0 && m2 == -2)
# return (20.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (9.0/16.0)*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/16.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*I*m*p_x*p_y/pow(p, 5) + (45.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/32.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) - 945.0/32.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) - 3.0/32.0*pow(p_x, 2)/pow(p, 2) - 3.0/32.0*I*p_x*p_y/pow(p, 2) + (3.0/32.0)*pow(p_y, 2)/pow(p, 2) + (9.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*pow(p_x, 2)/pow(p, 4) + (9.0/32.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*I*p_x*p_y/pow(p, 4) - 9.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*pow(p_y, 2)/pow(p, 4) + (315.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) + (315.0/32.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/32.0)*(pow(p, 2) - 7*pow(p_z, 2))*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 0 && m2 == -1)
# return (40.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/8.0)*m*p_x*p_z/pow(p, 3) + (9.0/8.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/16.0*m*p_x*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*m*p_x*p_z/pow(p, 5) - 45.0/16.0*I*m*p_y*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/32.0*m*p_x*pow(p_z, 3)/pow(p, 7) - 945.0/32.0*I*m*p_y*pow(p_z, 3)/pow(p, 7) - 3.0/32.0*p_x*p_z/pow(p, 2) - 3.0/32.0*I*p_y*p_z/pow(p, 2) + (9.0/32.0)*p_x*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*p_x*p_z/pow(p, 4) + (9.0/32.0)*I*p_y*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*I*p_y*p_z/pow(p, 4) + (315.0/32.0)*p_x*pow(p_z, 3)/pow(p, 6) + (315.0/32.0)*I*p_y*pow(p_z, 3)/pow(p, 6) : (3.0/32.0)*p_z*(3*pow(p, 2) - 7*pow(p_z, 2))*(p_x + I*p_y)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 0 && m2 == 0)
# return 80*Z * (fabs(p) > 1e-4 ? -3.0/32.0*m/p + (9.0/8.0)*m*pow(p_z, 2)/pow(p, 3) - 81.0/64.0*m/pow(p, 3) - 45.0/32.0*m*pow(p_z, 4)/pow(p, 5) + (405.0/32.0)*m*pow(p_z, 2)/pow(p, 5) - 945.0/64.0*m*pow(p_z, 4)/pow(p, 7) + 1.0/64.0 - 3.0/32.0*pow(p_z, 2)/pow(p, 2) + (27.0/64.0)/pow(p, 2) + (9.0/64.0)*pow(p_z, 4)/pow(p, 4) - 135.0/32.0*pow(p_z, 2)/pow(p, 4) + (315.0/64.0)*pow(p_z, 4)/pow(p, 6) : -1.0/64.0*(pow(p, 4) - 18*pow(p, 2)*pow(p_z, 2) + 21*pow(p_z, 4))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 0 && m2 == 1)
# return -40.0/3.0*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/8.0)*m*p_x*p_z/pow(p, 3) - 9.0/8.0*I*m*p_y*p_z/pow(p, 3) - 45.0/16.0*m*p_x*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*m*p_x*p_z/pow(p, 5) + (45.0/16.0)*I*m*p_y*pow(p_z, 3)/pow(p, 5) - 405.0/32.0*I*m*p_y*p_z/pow(p, 5) - 945.0/32.0*m*p_x*pow(p_z, 3)/pow(p, 7) + (945.0/32.0)*I*m*p_y*pow(p_z, 3)/pow(p, 7) - 3.0/32.0*p_x*p_z/pow(p, 2) + (3.0/32.0)*I*p_y*p_z/pow(p, 2) + (9.0/32.0)*p_x*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*p_x*p_z/pow(p, 4) - 9.0/32.0*I*p_y*pow(p_z, 3)/pow(p, 4) + (135.0/32.0)*I*p_y*p_z/pow(p, 4) + (315.0/32.0)*p_x*pow(p_z, 3)/pow(p, 6) - 315.0/32.0*I*p_y*pow(p_z, 3)/pow(p, 6) : (3.0/32.0)*p_z*(3*pow(p, 2) - 7*pow(p_z, 2))*(p_x - I*p_y)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 0 && m2 == 2)
# return (20.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) - 9.0/16.0*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*m*pow(p_x, 2)/pow(p, 5) + (45.0/16.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*I*m*p_x*p_y/pow(p, 5) + (45.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/32.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) - 3.0/32.0*pow(p_x, 2)/pow(p, 2) + (3.0/32.0)*I*p_x*p_y/pow(p, 2) + (3.0/32.0)*pow(p_y, 2)/pow(p, 2) + (9.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*pow(p_x, 2)/pow(p, 4) - 9.0/32.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*I*p_x*p_y/pow(p, 4) - 9.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*pow(p_y, 2)/pow(p, 4) + (315.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/32.0)*(pow(p, 2) - 7*pow(p_z, 2))*(pow(p_x, 2) - I*p_x*p_y - pow(p_y, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 1 && m2 == -2)
# return -20.0/3.0*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*p_x*p_z/pow(p, 3) - 9.0/16.0*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) - 45.0/4.0*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 5) + (45.0/4.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 5) + (135.0/16.0)*m*p_x*p_z/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)*p_z/pow(p, 5) - 135.0/16.0*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) - 945.0/8.0*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 7) + (945.0/8.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 7) + (945.0/16.0)*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) + (9.0/8.0)*I*pow(p_x, 2)*p_y*p_z/pow(p, 4) - 9.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 4) - 45.0/16.0*p_x*p_z/pow(p, 4) - 9.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 4) + (45.0/16.0)*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) + (315.0/8.0)*I*pow(p_x, 2)*p_y*p_z/pow(p, 6) - 315.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 6) - 315.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(pow(p, 2)*p_x - I*pow(p, 2)*p_y - 7*pow(p_x, 3) - 14*I*pow(p_x, 2)*p_y + 14*p_x*pow(p_y, 2) + 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 1 && m2 == -1)
# return -40.0/3.0*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (9.0/8.0)*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/8.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/4.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) + (135.0/8.0)*I*m*p_x*p_y/pow(p, 5) + (45.0/8.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/16.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) - 945.0/8.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) + (9.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/8.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) - 45.0/8.0*I*p_x*p_y/pow(p, 4) - 9.0/16.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/16.0)*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) + (315.0/8.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/16.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/16.0)*(pow(p, 2) - 7*pow(p_z, 2))*pow(p_x + I*p_y, 2)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 1 && m2 == 0)
# return -40.0/3.0*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/8.0)*m*p_x*p_z/pow(p, 3) + (9.0/8.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/16.0*m*p_x*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*m*p_x*p_z/pow(p, 5) - 45.0/16.0*I*m*p_y*pow(p_z, 3)/pow(p, 5) + (405.0/32.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/32.0*m*p_x*pow(p_z, 3)/pow(p, 7) - 945.0/32.0*I*m*p_y*pow(p_z, 3)/pow(p, 7) - 3.0/32.0*p_x*p_z/pow(p, 2) - 3.0/32.0*I*p_y*p_z/pow(p, 2) + (9.0/32.0)*p_x*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*p_x*p_z/pow(p, 4) + (9.0/32.0)*I*p_y*pow(p_z, 3)/pow(p, 4) - 135.0/32.0*I*p_y*p_z/pow(p, 4) + (315.0/32.0)*p_x*pow(p_z, 3)/pow(p, 6) + (315.0/32.0)*I*p_y*pow(p_z, 3)/pow(p, 6) : (3.0/32.0)*p_z*(3*pow(p, 2) - 7*pow(p_z, 2))*(p_x + I*p_y)/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 1 && m2 == 1)
# return (40.0/3.0)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (9.0/16.0)*m*pow(p_y, 2)/pow(p, 3) + (9.0/8.0)*m*pow(p_z, 2)/pow(p, 3) - 27.0/8.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/16.0)*m*pow(p_y, 2)/pow(p, 5) + (135.0/8.0)*m*pow(p_z, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) + (9.0/8.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/16.0)*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/16.0*pow(p_y, 2)/pow(p, 4) - 45.0/8.0*pow(p_z, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) + (315.0/16.0)*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/16.0)*(pow(p, 2)*pow(p_x, 2) + pow(p, 2)*pow(p_y, 2) + 2*pow(p, 2)*pow(p_z, 2) - 7*pow(p_x, 2)*pow(p_z, 2) - 7*pow(p_y, 2)*pow(p_z, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 1 && m2 == 2)
# return -20.0/3.0*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*p_x*p_z/pow(p, 3) - 27.0/16.0*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (405.0/16.0)*m*p_x*p_z/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)*p_z/pow(p, 5) - 405.0/16.0*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) + (945.0/16.0)*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 135.0/16.0*p_x*p_z/pow(p, 4) - 9.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 4) + (135.0/16.0)*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) - 315.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(3*pow(p, 2)*p_x - 3*I*pow(p, 2)*p_y - 7*pow(p_x, 3) + 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 2 && m2 == -2)
# return (10.0/3.0)*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (27.0/16.0)*m*pow(p_y, 2)/pow(p, 3) - 81.0/16.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 4)/pow(p, 5) - 45.0/4.0*I*m*pow(p_x, 3)*p_y/pow(p, 5) + (135.0/8.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 5) + (405.0/16.0)*m*pow(p_x, 2)/pow(p, 5) + (45.0/4.0)*I*m*p_x*pow(p_y, 3)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 4)/pow(p, 5) + (405.0/16.0)*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 4)/pow(p, 7) - 945.0/8.0*I*m*pow(p_x, 3)*p_y/pow(p, 7) + (2835.0/16.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 7) + (945.0/8.0)*I*m*p_x*pow(p_y, 3)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 4)/pow(p, 7) + (27.0/16.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 4)/pow(p, 4) + (9.0/8.0)*I*pow(p_x, 3)*p_y/pow(p, 4) - 27.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 4) - 135.0/16.0*pow(p_x, 2)/pow(p, 4) - 9.0/8.0*I*p_x*pow(p_y, 3)/pow(p, 4) + (9.0/16.0)*pow(p_y, 4)/pow(p, 4) - 135.0/16.0*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 4)/pow(p, 6) + (315.0/8.0)*I*pow(p_x, 3)*p_y/pow(p, 6) - 945.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 6) - 315.0/8.0*I*p_x*pow(p_y, 3)/pow(p, 6) + (315.0/16.0)*pow(p_y, 4)/pow(p, 6) : (3.0/16.0)*(3*pow(p, 2)*pow(p_x, 2) + 3*pow(p, 2)*pow(p_y, 2) - 7*pow(p_x, 4) - 14*I*pow(p_x, 3)*p_y + 21*pow(p_x, 2)*pow(p_y, 2) + 14*I*p_x*pow(p_y, 3) - 7*pow(p_y, 4))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 2 && m2 == -1)
# return (20.0/3.0)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*p_x*p_z/pow(p, 3) - 9.0/16.0*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) - 45.0/4.0*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 5) + (45.0/4.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 5) + (135.0/16.0)*m*p_x*p_z/pow(p, 5) + (45.0/8.0)*I*m*pow(p_y, 3)*p_z/pow(p, 5) - 135.0/16.0*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) - 945.0/8.0*I*m*pow(p_x, 2)*p_y*p_z/pow(p, 7) + (945.0/8.0)*m*p_x*pow(p_y, 2)*p_z/pow(p, 7) + (945.0/16.0)*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) + (9.0/8.0)*I*pow(p_x, 2)*p_y*p_z/pow(p, 4) - 9.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 4) - 45.0/16.0*p_x*p_z/pow(p, 4) - 9.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 4) + (45.0/16.0)*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) + (315.0/8.0)*I*pow(p_x, 2)*p_y*p_z/pow(p, 6) - 315.0/8.0*p_x*pow(p_y, 2)*p_z/pow(p, 6) - 315.0/16.0*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(pow(p, 2)*p_x - I*pow(p, 2)*p_y - 7*pow(p_x, 3) - 14*I*pow(p_x, 2)*p_y + 14*p_x*pow(p_y, 2) + 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 2 && m2 == 0)
# return (20.0/3.0)*sqrt(6)*Z * (fabs(p) > 1e-4 ? (9.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (9.0/16.0)*I*m*p_x*p_y/pow(p, 3) - 9.0/16.0*m*pow(p_y, 2)/pow(p, 3) - 45.0/16.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/16.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 5) + (135.0/32.0)*I*m*p_x*p_y/pow(p, 5) + (45.0/16.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 5) - 135.0/32.0*m*pow(p_y, 2)/pow(p, 5) - 945.0/32.0*m*pow(p_x, 2)*pow(p_z, 2)/pow(p, 7) - 945.0/32.0*I*m*p_x*p_y*pow(p_z, 2)/pow(p, 7) + (945.0/32.0)*m*pow(p_y, 2)*pow(p_z, 2)/pow(p, 7) - 3.0/32.0*pow(p_x, 2)/pow(p, 2) - 3.0/32.0*I*p_x*p_y/pow(p, 2) + (3.0/32.0)*pow(p_y, 2)/pow(p, 2) + (9.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*pow(p_x, 2)/pow(p, 4) + (9.0/32.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 4) - 45.0/32.0*I*p_x*p_y/pow(p, 4) - 9.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 4) + (45.0/32.0)*pow(p_y, 2)/pow(p, 4) + (315.0/32.0)*pow(p_x, 2)*pow(p_z, 2)/pow(p, 6) + (315.0/32.0)*I*p_x*p_y*pow(p_z, 2)/pow(p, 6) - 315.0/32.0*pow(p_y, 2)*pow(p_z, 2)/pow(p, 6) : (3.0/32.0)*(pow(p, 2) - 7*pow(p_z, 2))*(pow(p_x, 2) + I*p_x*p_y - pow(p_y, 2))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 2 && m2 == 1)
# return -20.0/3.0*Z * (fabs(p) > 1e-4 ? (27.0/16.0)*m*p_x*p_z/pow(p, 3) + (27.0/16.0)*I*m*p_y*p_z/pow(p, 3) - 45.0/8.0*m*pow(p_x, 3)*p_z/pow(p, 5) + (405.0/16.0)*m*p_x*p_z/pow(p, 5) - 45.0/8.0*I*m*pow(p_y, 3)*p_z/pow(p, 5) + (405.0/16.0)*I*m*p_y*p_z/pow(p, 5) - 945.0/16.0*m*pow(p_x, 3)*p_z/pow(p, 7) - 945.0/16.0*I*m*pow(p_y, 3)*p_z/pow(p, 7) + (9.0/16.0)*pow(p_x, 3)*p_z/pow(p, 4) - 135.0/16.0*p_x*p_z/pow(p, 4) + (9.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 4) - 135.0/16.0*I*p_y*p_z/pow(p, 4) + (315.0/16.0)*pow(p_x, 3)*p_z/pow(p, 6) + (315.0/16.0)*I*pow(p_y, 3)*p_z/pow(p, 6) : (3.0/16.0)*p_z*(3*pow(p, 2)*p_x + 3*I*pow(p, 2)*p_y - 7*pow(p_x, 3) - 7*I*pow(p_y, 3))/pow(p, 4));
# if (l1 == 2 && l2 == 2 && m1 == 2 && m2 == 2)
# return (10.0/3.0)*Z * (fabs(p) > 1e-4 ? (45.0/16.0)*m*pow(p_x, 2)/pow(p, 3) + (45.0/16.0)*m*pow(p_y, 2)/pow(p, 3) - 135.0/16.0*m/pow(p, 3) - 45.0/8.0*m*pow(p_x, 4)/pow(p, 5) + (45.0/8.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 5) + (675.0/16.0)*m*pow(p_x, 2)/pow(p, 5) - 45.0/8.0*m*pow(p_y, 4)/pow(p, 5) + (675.0/16.0)*m*pow(p_y, 2)/pow(p, 5) - 945.0/16.0*m*pow(p_x, 4)/pow(p, 7) + (945.0/16.0)*m*pow(p_x, 2)*pow(p_y, 2)/pow(p, 7) - 945.0/16.0*m*pow(p_y, 4)/pow(p, 7) + (45.0/16.0)/pow(p, 2) + (9.0/16.0)*pow(p_x, 4)/pow(p, 4) - 9.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 4) - 225.0/16.0*pow(p_x, 2)/pow(p, 4) + (9.0/16.0)*pow(p_y, 4)/pow(p, 4) - 225.0/16.0*pow(p_y, 2)/pow(p, 4) + (315.0/16.0)*pow(p_x, 4)/pow(p, 6) - 315.0/16.0*pow(p_x, 2)*pow(p_y, 2)/pow(p, 6) + (315.0/16.0)*pow(p_y, 4)/pow(p, 6) : (3.0/16.0)*(5*pow(p, 2)*pow(p_x, 2) + 5*pow(p, 2)*pow(p_y, 2) - 7*pow(p_x, 4) + 7*pow(p_x, 2)*pow(p_y, 2) - 7*pow(p_y, 4))/pow(p, 4));
